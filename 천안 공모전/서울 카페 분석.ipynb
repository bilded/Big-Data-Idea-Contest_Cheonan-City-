# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='NanumMyeongjoOTF') # For MacOS
print(plt.rcParams['font.family'])
# Out:
# ['NanumMyeongjoOTF']

# %%
df = pd.read_csv('소상공인시장진흥공단_상가(상권)정보_서울_202406.csv',encoding='UTF8')
df
# Out:
# /var/folders/6y/9r5t2yv91tv_xlty4q28bqn40000gn/T/ipykernel_54751/894687091.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('소상공인시장진흥공단_상가(상권)정보_서울_202406.csv',encoding='UTF8')
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0037544       영자's곱창  NaN        I2       음식      I201
# 1       MA0101202210A0097916        호텔클로이  NaN        I1       숙박      I101
# 2       MA0101202210A0096343    나라차중계태권도장  NaN        P1       교육      P106
# 3       MA0101202210A0093845        이상한스냅  NaN        M1    과학·기술      M113
# 4       MA010120220805430767          토끼정  NaN        I2       음식      I201
# ...                      ...          ...  ...       ...      ...       ...
# 460432  MA0101202310A0038359  마스터부동산중개사무소  NaN        L1      부동산      L102
# 460433  MA0101202310A0035270   그릿뷰티아카데미학원  NaN        P1       교육      P106
# ...

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104524 entries, 0 to 104523
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     104524 non-null  object
#  1   상호명        104524 non-null  object
#  2   지점명        1553 non-null    object
#  3   상권업종대분류코드  104524 non-null  object
#  4   상권업종대분류명   104524 non-null  object
#  5   상권업종중분류코드  104524 non-null  object
#  6   상권업종중분류명   104524 non-null  object
#  7   상권업종소분류코드  104524 non-null  object
#  8   상권업종소분류명   104524 non-null  object
#  9   표준산업분류코드   104486 non-null  object
#  10  표준산업분류명    104486 non-null  object
#  11  시도코드       104524 non-null  int64
#  12  시도명        104524 non-null  object
#  13  시군구코드      104524 non-null  int64
#  14  시군구명       104524 non-null  object
#  15  행정동코드      104524 non-null  int64
#  16  행정동명       104524 non-null  object
#  17  법정동코드      104524 non-null  int64
#  18  법정동명       104524 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df['상권업종소분류명']
# Out:
# 0              곱창 전골/구이
# 1                 여관/모텔
# 2              태권도/무술학원
# 3                 사진촬영업
# 4                백반/한정식
#               ...
# 460432       부동산 중개/대리업
# 460433    기타 기술/직업 훈련학원
# 460434         가전제품 수리업
# 460435              노래방
# 460436         곱창 전골/구이
# Name: 상권업종소분류명, Length: 460437, dtype: object

# %%
df[df['상권업종소분류명'] == '카페']
# Out:
#                       상가업소번호         상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 10      MA010120220805430763         카페숲   NaN        I2       음식      I212
# 66      MA010120220805433645     매머드커피외대   NaN        I2       음식      I212
# 68      MA010120220805433429        포르마레   NaN        I2       음식      I212
# 111     MA010120220805435869       카페브릿지   NaN        I2       음식      I212
# 146     MA010120220805435782  더웨이유통할리스커피   NaN        I2       음식      I212
# ...                      ...         ...   ...       ...      ...       ...
# 460382  MA0101202310A0038401      빽다방빨래골   입구점        I2       음식      I212
# 460413  MA0101202310A0036587         청23   NaN        I2       음식      I212
# 460421  MA0101202310A0041469        피트커피   NaN        I2       음식      I212
# 460424  MA0101202310A0044212        빽다방동  여의도점        I2       음식      I212
# 460426  MA0101202310A0040088       보광동커피   NaN        I2       음식      I212
#
# ...

# %%
df['상권업종소분류명'].value_counts()
# Out:
# 부동산 중개/대리업       23470
# 백반/한정식           21332
# 카페               20201
# 경영 컨설팅업          18986
# 미용실              18160
#                  ...
# 얼음 소매업              24
# 기타 회계 관련 서비스업       24
# 음반/비디오물 대여업         21
# 캠핑/글램핑              13
# 가축 사료 소매업           12
# Name: 상권업종소분류명, Length: 247, dtype: int64

# %%
df[df['상호명'] == '유우링']
# Out:
#                      상가업소번호  상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 75635  MA010120220809831209  유우링  NaN        I2       음식      I212    비알코올
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 75635    I21201       카페   I56221  ...  1171010400100470000012352  NaN
#
#                       도로명주소   구우편번호 신우편번호  동정보 층정보  호정보          경도         위도
# 75635  서울특별시 송파구 백제고분로43길 4  138849  5621  NaN   1  NaN  127.110074  37.508016
#
# [1 rows x 39 columns]

# %%
df[df['상호명'] == '포동푸딩']
# Out:
#                       상가업소번호   상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 374126  MA010120220804838224  포동푸딩  NaN        I2       음식      I212    비알코올
#
#        상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 374126    I21201       카페   I56221  ...  1117012800100400364012821  NaN
#
#                         도로명주소   구우편번호 신우편번호  동정보 층정보  호정보          경도  \
# 374126  서울특별시 용산구 한강대로7길 23-9  140880  4380  NaN   1  NaN  126.961428
#
#               위도
# 374126  37.52431
#
# [1 rows x 39 columns]

# %%
df[df['상호명'] == '카페브릿지']
# Out:
#                       상가업소번호    상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 111     MA010120220805435869  카페브릿지  NaN        I2       음식      I212
# 302819  MA010120220803601653  카페브릿지  NaN        I2       음식      I212
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 111       비알코올     I21201       카페   I56221  ...  1156011000100220000000001
# 302819    비알코올     I21201       카페   I56221  ...  1111016900100740038008765
#
#          건물명                도로명주소   구우편번호 신우편번호  동정보 층정보  호정보          경도  \
# 111      파크원  서울특별시 영등포구 여의대로 108  150875  7335  NaN  18  NaN  126.929094
# 302819  성인빌딩   서울특별시 종로구 혜화로 10-3  110530  3076  NaN   3  NaN  127.000453
#
#                위도
# 111     37.525184
# 302819  37.586621
#
# [2 rows x 39 columns]
