# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('충청남도(640000)_관광지정보표준데이터.csv', encoding='cp949')
df
# Out:
#             관광지명 관광지구분                     소재지도로명주소                   소재지지번주소  \
# 0           사계고택   관광지       충청남도 계룡시 두마면 사계로 122-4       충청남도 계룡시 두마면 두계리 96
# 1            모원재   관광지        충청남도 계룡시 두마면 왕대2길6-10    충청남도 계룡시 두마면 왕대리 281-1
# 2            염선재   관광지       충청남도 계룡시 사계로 5-16(금암동)           충청남도 계룡시 금암동 45
# 3      이심원충신정려현판   관광지        충청남도 계룡시 금암1 길 7(금암동)        충청남도 계룡시 금암동 281-4
# 4            신원재   관광지          충청남도 계룡시 두마면 왕대2길43      충청남도 계룡시 두마면 왕대리 299
# 5         마곡사관광지   관광지                          NaN    충청남도 공주시 사곡면 운암리 731-2
# 6        공주문화관광지   관광지                          NaN          충청남도 공주시 웅진동 431
# 7         삽교호관광지   관광지       충청남도 당진시 신평면 삽교천3길 100                       NaN
# 8        왜목마을관광지   관광지        충청남도 당진시 석문면 왜목길 15-5                       NaN
# 9         난지섬관광지   관광지         충청남도 당진시 석문면 난지1길 67                       NaN
# 10        대천해수욕장   관광지             충청남도 보령시 머드로 123                       NaN
# ...

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   관광지명       30 non-null     object
#  1   관광지구분      30 non-null     object
#  2   소재지도로명주소   26 non-null     object
#  3   소재지지번주소    17 non-null     object
#  4   위도         30 non-null     float64
#  5   경도         30 non-null     float64
#  6   면적         30 non-null     float64
#  7   공공편익시설정보   30 non-null     object
#  8   숙박시설정보     7 non-null      object
#  9   운동및오락시설정보  7 non-null      object
#  10  휴양및문화시설정보  9 non-null      object
#  11  접객시설정보     3 non-null      object
#  12  지원시설정보     0 non-null      float64
#  13  지정일자       30 non-null     object
#  14  수용인원수      30 non-null     int64
#  15  주차가능수      30 non-null     int64
#  16  관광지소개      30 non-null     object
#  17  관리기관전화번호   30 non-null     object
#  18  관리기관명      30 non-null     object
# ...

# %%
df.isnull().sum()  # null값 알아보기
# Out:
# 관광지명          0
# 관광지구분         0
# 소재지도로명주소      4
# 소재지지번주소      13
# 위도            0
# 경도            0
# 면적            0
# 공공편익시설정보      0
# 숙박시설정보       23
# 운동및오락시설정보    23
# 휴양및문화시설정보    21
# 접객시설정보       27
# 지원시설정보       30
# 지정일자          0
# 수용인원수         0
# 주차가능수         0
# 관광지소개         0
# 관리기관전화번호      0
# 관리기관명         0
# 데이터기준일자       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['관광지명', '관광지구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '면적', '공공편익시설정보',
#        '숙박시설정보', '운동및오락시설정보', '휴양및문화시설정보', '접객시설정보', '지원시설정보', '지정일자', '수용인원수',
#        '주차가능수', '관광지소개', '관리기관전화번호', '관리기관명', '데이터기준일자'],
#       dtype='object')

# %%
import folium

# %%
df['위도']
# Out:
# 0     36.265691
# 1     36.254886
# 2     36.269392
# 3     36.280034
# 4     36.255245
# 5     36.556171
# 6     36.470222
# 7     36.888905
# 8     37.044933
# 9     37.047036
# 10    36.315540
# 11    36.244577
# 12    36.287188
# 13    36.145949
# 14    36.303867
# 15    36.606253
# 16    36.727358
# 17    36.629513
# 18    36.751880
# 19    36.713557
# 20    36.019936
# 21    36.163349
# 22    36.771521
# 23    36.698848
# 24    36.638013
# 25    36.690756
# 26    36.757312
# 27    36.822077
# 28    36.790008
# 29    36.539234
# Name: 위도, dtype: float64

# %%
df['경도']
# Out:
# 0     127.271724
# 1     127.273275
# 2     127.261851
# 3     127.247077
# 4     127.270342
# 5     127.020592
# 6     127.111701
# 7     126.824754
# 8     126.524615
# 9     126.424209
# 10    126.510856
# 11    126.536543
# 12    126.906814
# 13    126.824846
# 14    126.900773
# 15    126.417754
# 16    126.413146
# 17    126.378389
# 18    126.607638
# 19    126.550384
# 20    126.736726
# 21    126.524336
# 22    126.983915
# 23    126.966607
# 24    126.799434
# 25    126.659328
# 26    127.224096
# 27    127.188956
# 28    126.146571
# 29    126.471915
# Name: 경도, dtype: float64

# %%
plt.scatter(df['경도'], df['위도'])

# %%
# !pip install folium
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
df['위도'][0]
# Out:
# 36.265691

# %%
df['경도'][0]
# Out:
# 127.271724

# %%
map = folium.Map(location=[df['위도'][0], df['경도'][0]])
folium.Marker(location=[df['위도'][0], df['경도'][0]],popup=df['관광지명'][0]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
len(df)
# Out:
# 30

# %%
df= df.fillna('missing')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   관광지명       30 non-null     object
#  1   관광지구분      30 non-null     object
#  2   소재지도로명주소   30 non-null     object
#  3   소재지지번주소    30 non-null     object
#  4   위도         30 non-null     float64
#  5   경도         30 non-null     float64
#  6   면적         30 non-null     float64
#  7   공공편익시설정보   30 non-null     object
#  8   숙박시설정보     30 non-null     object
#  9   운동및오락시설정보  30 non-null     object
#  10  휴양및문화시설정보  30 non-null     object
#  11  접객시설정보     30 non-null     object
#  12  지원시설정보     30 non-null     object
#  13  지정일자       30 non-null     object
#  14  수용인원수      30 non-null     int64
#  15  주차가능수      30 non-null     int64
#  16  관광지소개      30 non-null     object
#  17  관리기관전화번호   30 non-null     object
#  18  관리기관명      30 non-null     object
# ...

# %%
for i in range(len(df)):
    print(df['관광지명'][i])
# Out:
# 사계고택
# 모원재
# 염선재
# 이심원충신정려현판
# 신원재
# 마곡사관광지
# 공주문화관광지
# 삽교호관광지
# 왜목마을관광지
# 난지섬관광지
# 대천해수욕장
# 무창포해수욕장
# 구드래관광지
# 서동요역사관광지
# 백제문화관광단지
# 간월도관광지
# 서산류방택천문기상과학관
# 서산버드랜드
# 용현자연휴양림
# 해미읍성
# 금강하구둑관광지
# 춘장대
# 신정호국민관광지
# 아산온천관광지
# 예당관광지
# 덕산온천관광단지
# 천안종합휴양관광지
# 태조산관광지
# 만리포 관광지
# 남당

# %%
m = folium.Map(location=[df['위도'].mean(), df['경도'].mean()])

# %%
for i in range(len(df)):
    folium.Marker(location=[df['위도'][i], df['경도'][i]],
                  popup=df['관광지명'][i]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
plt.scatter(df['경도'], df['위도'])

# %%
import requests
import json

# 서울 행정구역 json raw파일(githubcontent)
r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

# %%
m = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=11, 
)

folium.GeoJson(
    seoul_geo,
    name='지역구'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
import json
map_osm = folium.Map(location=[37.566345, 126.977893])
rfile = open('d:/temp/chicken_data/skorea_provinces_geo_simple.json', 'r', encoding='cp949').read()
jsonData = json.loads(rfile)
folium.GeoJson(jsonData, name='json_data').add_to(map_osm)
map_osm.save('d:/temp/chicken_data/map7.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 4
#       2 import json
#       3 map_osm = folium.Map(location=[37.566345, 126.977893])
# ----> 4 rfile = open('d:/temp/chicken_data/skorea_provinces_geo_simple.json', 'r', encoding='cp949').read()
#       5 jsonData = json.loads(rfile)
#       6 folium.GeoJson(jsonData, name='json_data').add_to(map_osm)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...
